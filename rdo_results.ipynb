# %%
import numpy as np
import matplotlib.pyplot as plt
from bjontegaard_metric import *

# %%
rate_ori = np.array([0.0942, 0.1421, 0.2087, 0.3125])
psnr_ori = np.array([27.90, 29.68, 31.22, 33.15])

rate_irdo = np.array([0.09171, 0.1375, 0.2019, 0.3024])
psnr_irdo = np.array([28.25, 30.04, 31.55, 33.41])

plt.plot(rate_ori, psnr_ori, marker='o', label='EEV 0.4')
plt.plot(rate_irdo, psnr_irdo, marker='s', label='EEV 0.4 + I-RDO')
plt.legend()
plt.grid()
plt.show()
print(BD_RATE(rate_ori, psnr_ori, rate_irdo, psnr_irdo))
print(BD_PSNR(rate_ori, psnr_ori, rate_irdo, psnr_irdo, 0.10, 0.30))
# Out:
# -10.476185069282728
# 0.4744155383517735
